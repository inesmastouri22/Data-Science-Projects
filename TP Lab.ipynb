# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\house.csv")
df
# Out:
#      loyer  surface
# 0     1330       37
# 1     1400       32
# 2      904       26
# 3      955        3
# 4     2545        7
# ..     ...      ...
# 540   1490       48
# 541   2020       58
# 542   2050        7
# 543   1220       42
# 544   1610       44
#
# [545 rows x 2 columns]

# %%
plt.plot(df['surface'], df['loyer'], 'go', markersize=4)

# %%
regresseur = linear_model.LinearRegression()

# %%
x = np.array(df['surface']).reshape(-1, 1)#infinite columns, and 1 line

# %%
y = df['loyer']

# %%
x
# Out:
# array([[ 37],
#        [ 32],
#        [ 26],
#        [  3],
#        [  7],
#        [ 24],
#        [ 41],
#        [ 67],
#        [ 63],
#        [  7],
#        [ 81],
#        [347],
#        [ 26],
#        [ 36],
#        [ 19],
#        [  2],
#        [ 25],
#        [ 35],
#        [ 12],
#        [  4],
#        [  3],
#        [ 25],
#        [ 21],
#        [ 44],
#        [ 35],
#        [ 54],
#        [ 39],
#        [ 34],
#        [ 28],
#        [ 32],
#        [  4],
#        [ 42],
#        [ 31],
#        [ 33],
#        [ 39],
#        [ 47],
#        [ 33],
#        [ 37],
#        [ 42],
#        [ 46],
#        [ 37],
#        [ 46],
#        [ 42],
#        [ 49],
#        [ 48],
#        [  5],
#        [ 54],
#        [ 54],
#        [ 45],
#        [ 53],
#        [  4],
#        [ 35],
#        [  4],
#        [ 35],
#        [  6],
#        [  3],
#        [ 34],
#        [ 64],
#        [ 47],
#        [ 43],
#        [ 62],
#        [  5],
# ...

# %%
y
# Out:
# 0      1330
# 1      1400
# 2       904
# 3       955
# 4      2545
#        ...
# 540    1490
# 541    2020
# 542    2050
# 543    1220
# 544    1610
# Name: loyer, Length: 545, dtype: int64

# %%
regresseur.fit(x,y)
# Out:
# LinearRegression()

# %%
precision = regresseur.score(x,y)

# %%
precision
# Out:
# 0.4724114649108153

# %%
print(precision *100)
# Out:
# 47.24114649108153

# %%
prediction = regresseur.predict(np.array([50,70,120]).reshape(-1, 1))

# %%
print(prediction)
# Out:
# [2320.03826712 2916.70687654 4408.37840009]

# %%
print(str(regresseur.intercept_)+'  '+str(regresseur.coef_))
# Out:
# 828.3667435601967  [29.83343047]

# %%
plt.plot([0, 250], 
         [regresseur.intercept_, regresseur.coef_[0] * 250 + regresseur.intercept_], 
         linestyle='--', color='blue')

# %%
plt.show()
